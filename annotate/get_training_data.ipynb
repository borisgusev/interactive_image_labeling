# %%
import os
import pandas as pd
import numpy as np
import itertools
import random
from tifffile import imread, imwrite
import matplotlib.pyplot as plt

database = "../training_database_classifier.csv"
datab_df = pd.read_csv(database)

raw_images = list(datab_df["raw"])
sobel = list(datab_df["sobel"])



# os.makedirs(database_dir, exist_ok=True)

# # Load the data
# data = sorted([os.path.join(data_folder, f) for f in os.listdir(data_folder)])
# max_number_of_frames = 299
# frame_range = list(range(max_number_of_frames ))

# combinations = list(itertools.product(data, frame_range))
# random.shuffle(combinations)

# data = random.sample(combinations, 1000)
# print(data)

# for d in data:
#     img_path = d[0]
#     image = imread(img_path)
#     frame = image[d[1]]
#     imwrite(os.path.join(database_dir, f"{d[0].split('/')[-1].split('.')[0]}_{d[1]}.tiff"), frame)
# Out:
# [('/mnt/external.data/TowbinLab/kstojanovski/20220629_Ti2_20x_160-182-190_pumping_25C_20220629_154238_325/analysis/str_pharynx_videos/Time00132_Point0024_Channel575_nm_Seq6805_pharynx.tiff', 43), ('/mnt/external.data/TowbinLab/kstojanovski/20220629_Ti2_20x_160-182-190_pumping_25C_20220629_154238_325/analysis/str_pharynx_videos/Time00043_Point0019_Channel575_nm_Seq2231_pharynx.tiff', 113), ('/mnt/external.data/TowbinLab/kstojanovski/20220629_Ti2_20x_160-182-190_pumping_25C_20220629_154238_325/analysis/str_pharynx_videos/Time00190_Point0028_Channel575_nm_Seq9787_pharynx.tiff', 56), ('/mnt/external.data/TowbinLab/kstojanovski/20220629_Ti2_20x_160-182-190_pumping_25C_20220629_154238_325/analysis/str_pharynx_videos/Time00123_Point0015_Channel575_nm_Seq6333_pharynx.tiff', 75), ('/mnt/external.data/TowbinLab/kstojanovski/20220629_Ti2_20x_160-182-190_pumping_25C_20220629_154238_325/analysis/str_pharynx_videos/Time00240_Point0024_Channel575_nm_Seq12349_pharynx.tiff', 272), ('/mnt/external.dat
# ...
